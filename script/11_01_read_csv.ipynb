# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
path = 'C:/Users/sdjhs/git/data/DL'

# %%
dataset = pd.read_csv(f'{path}/richgo_data.csv')

# %%
len(dataset)
# Out:
# 34789045

# %%
dataset['INDICATOR_ID'].unique()
# Out:
# array(['GDP대비시가총액', 'M1통화량대비시가총액', 'M2통화량대비시가총액', 'R-HAI(KB)',
#        'R-HAI(리치고)', 'R-JHAI(KB)', 'R-JHAI(리치고)', 'R-JPIR(KB)',
#        'R-JPIR(리치고)', 'R-PIR(KB)', 'R-PIR(리치고)', 'R-ROI(KB)', '갭금액(KB)',
#        '갭금액(리치고)', '거주환경', '거주환경-교육-유아시설', '거주환경-교육-유치원',
#        '거주환경-교육-초등학교접근성', '거주환경-교육-학원', '거주환경-교통-버스접근성', '거주환경-교통-지하철접근성',
#        '거주환경-생활편의-공원/테마파크', '거주환경-생활편의-도서관/대형서점', '거주환경-생활편의-마트/백화점',
#        '거주환경-생활편의-유흥시설클린지수', '거주환경-생활편의-카페', '거주환경-의료-병원', '거주환경-의료-요양시설',
#        '경기선행지수_리치고', '경기선행지수_한국은행', '경매수_아파트', '경매수_전체', '국민순자산대비아파트시가총액',
#        '매각률_아파트', '매각률_전체', '매매10분위시세(KB)', '매매10분위시세증감률(KB)',
#        '매매1분위시세(KB)', '매매2분위시세(KB)', '매매3분위시세(KB)', '매매4분위시세(KB)',
#        '매매5분위시세(KB)', '매매6분위시세(KB)', '매매7분위시세(KB)', '매매8분위시세(KB)',
#        '매매9분위시세(KB)', '매매시세(KB)', '매매시세(리치고)', '매매시세증감률(KB)',
#        '매매시세증감률(리치고)', '매물가격(매매)', '매물가격(월세)', '매물가격(전세)', '매물량(매매)',
#        '매물량(월세)', '매물량(전세)', '매물량(전월세)', '매물지수(매매)', '매물지수(월세)',
# ...

# %%
pd.to_datetime(dataset['YYYYMMDD'].unique()).sort_values()
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '2023-04-01', '2023-05-01', '2023-06-01', '2023-06-27',
#                '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#                '2023-11-01', '2023-12-01'],
#               dtype='datetime64[ns]', length=649, freq=None)
